# %% [markdown]
# # Lab Instructions
#
# You have been hired by a record executive to design a guaranteed smash hit song based on data.  The exec has decided that if you make a song that has all the most popular features of recent songs then it will definitely be a hit.  So if - for example - the most common key in the Spotify data is C# then we would want the song we are designing to also be in C#.  If a "typical" value of BPM is between 120 and 130 then we would want the song we are designing to also have a tempo between 120 and 130 BMP.
#
# Visualize and describe the distribution of:
# * BPM
# * Key
# * Mode
# * Danceability
# * Energy
# * Speechiness
# * Acousticness
#
# Based on your visualizations and calculations, what values for each of these features would make a song a guaranteed smash hit?  For quantitative features, you should propose a range of values.
#
# Use a large language model to help you write code to identify if there are any songs in the Spotify dataset that meet all of the criteria we determined.  What is/are the artist(s) and title(s) of the song?  Were any of these songs actually popular?
#
# Pick a song that you know was a smash hit. How do the values of BPM, key, mode, danceability, etc. compare to other songs?
#
# **Hint:**  Import the Spotify data using `df = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')`.

# %%
import pandas as pd

df = pd.read_csv('spotify-2023.csv', encoding='ISO-8859-1')

df.head()
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# 25%              875.000000           0.000000           13.000000
# 50%             2224.000000           3.000000           34.000000
# 75%             5542.000000          16.000000           88.000000
# max            52898.000000         147.000000          672.000000
#
#        in_apple_charts  in_deezer_charts         bpm  danceability_%  \
# count       953.000000        953.000000  953.000000       953.00000
# mean         51.908709          2.666317  122.540399        66.96957
# std          50.630241          6.035599   28.057802        14.63061
# min           0.000000          0.000000   65.000000        23.00000
# 25%           7.000000          0.000000  100.000000        57.00000
# 50%          38.000000          0.000000  121.000000        69.00000
# 75%          87.000000          2.000000  140.000000        78.00000
# max         275.000000         58.000000  206.000000        96.00000
#
#         valence_%    energy_%  acousticness_%  instrumentalness_%  liveness_%  \
# count  953.000000  953.000000      953.000000          953.000000  953.000000
# mean    51.431270   64.279119       27.057712            1.581322   18.213012
# std     23.480632   16.550526       25.996077            8.409800   13.711223
# min      4.000000    9.000000        0.000000            0.000000    3.000000
# 25%     32.000000   53.000000        6.000000            0.000000   10.000000
# 50%     51.000000   66.000000       18.000000            0.000000   12.000000
# 75%     70.000000   77.000000       43.000000            0.000000   24.000000
# max     97.000000   97.000000       97.000000           91.000000   97.000000
#
#        speechiness_%
# count     953.000000
# mean       10.131165
# std         9.912888
# min         2.000000
# 25%         4.000000
# 50%         6.000000
# 75%        11.000000
# max        64.000000

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,5))
df['bpm'].plot(kind='hist', bins=20, title='Distribution of BPM')
plt.xlabel('BPM')
plt.show()

# %% [markdown]
# The BPM distribution shows that most songs fall between about 90 and 130 BPM. There are fewer songs at very slow or very fast tempos. This suggests that a lot of popular music stays within a comfortable mid‑tempo range.

# %%
plt.figure(figsize=(8,5))
df['key'].value_counts().plot(kind='bar', title='Distribution of Musical Keys')
plt.xlabel('Key')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The key distribution is fairly even across all keys. There is no single key that dominates the dataset, so key choice does not seem to strongly influence popularity.

# %%
plt.figure(figsize=(6,4))
df['mode'].value_counts().plot(kind='bar', title='Distribution of Mode')
plt.xlabel('Mode')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The mode distribution shows a slight lean toward major mode, but both major and minor are represented. This suggests that mode alone is not a strong predictor of popularity.

# %%
plt.figure(figsize=(8,5))
df['danceability_%'].plot(kind='hist', bins=20, title='Distribution of Danceability')
plt.xlabel('Danceability (%)')
plt.show()

# %% [markdown]
# The danceability distribution leans toward higher values. Many songs fall between 0.6 and 0.8, which means a large portion of the dataset is made up of tracks that are easy to move to.

# %%
plt.figure(figsize=(8,5))
df['energy_%'].plot(kind='hist', bins=20, title='Distribution of Energy')
plt.xlabel('Energy (%)')
plt.show()

# %% [markdown]
# The energy distribution is also generally high. Most songs land between 0.55 and 0.85. This reflects the trend of modern music having strong percussion and energetic production.

# %%
plt.figure(figsize=(8,5))
df['speechiness_%'].plot(kind='hist', bins=20, title='Distribution of Speechiness')
plt.xlabel('Speechiness (%)')
plt.show()

# %% [markdown]
# The speechiness distribution is heavily skewed toward low values. Most songs fall below 0.1, which means they contain very little spoken content. Only a small group of songs, usually rap or hip‑hop, show higher speechiness.

# %%
plt.figure(figsize=(8,5))
df['acousticness_%'].plot(kind='hist', bins=20, title='Distribution of Acousticness')
plt.xlabel('Acousticness (%)')
plt.show()

# %% [markdown]
# The acousticness distribution is skewed toward low values. This shows that most songs rely on electronic or studio‑produced sounds rather than acoustic instruments.

# %%
df['bpm'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# For creating a “hit recipe,” the ranges that seem most common in successful songs are: BPM between 95 and 125, danceability between 0.6 and 0.85, energy between 0.6 and 0.85, speechiness between 0.03 and 0.10, acousticness between 0.0 and 0.35, and major mode. Key does not appear to matter much.

# %%
df['bpm'].describe()
# Out:
# count    953.000000
# mean     122.540399
# std       28.057802
# min       65.000000
# 25%      100.000000
# 50%      121.000000
# 75%      140.000000
# max      206.000000
# Name: bpm, dtype: float64

# %%
df['mode'].value_counts().plot(kind='pie')
# Out:
# <Axes: ylabel='count'>

# %%
df['mode'].value_counts()
# Out:
# mode
# Major    550
# Minor    403
# Name: count, dtype: int64

# %%
filtered_df = df.loc[(df['bpm'] >= 85) & (df['bpm'] <= 140) & (df['mode'] == 'Minor') & (df['key'] == 'A') ]

filtered_df.head()
# Out:
#               track_name        artist(s)_name  artist_count  released_year  \
# 93      Donï¿½ï¿½ï¿½t Bl          Taylor Swift             1           2017
# 120                 LUNA  Junior H, Peso Pluma             2           2023
# 131                  OMG              NewJeans             1           2023
# 150       Mi Bello Angel         Natanael Cano             1           2023
# 159  Under The Influence           Chris Brown             1           2019
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 93               11             8                  4875                 23
# 120               6            22                   201                 11
# 131               1             2                  1783                 27
# 150               6            30                    86                  8
# 159              10             4                  3859                 26
#
#        streams  in_apple_playlists  ...  bpm key   mode danceability_%  \
# 93   685032533                  19  ...  136   A  Minor             62
# 120   55842345                  19  ...  128   A  Minor             75
# 131  430977451                  26  ...  127   A  Minor             80
# 150   31873544                   7  ...  128   A  Minor             81
# 159  929964809                 133  ...  117   A  Minor             73
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 93          19       53             11                   0           6
# 120         79       63             33                   0          15
# 131         74       77             36                   0          11
# 150         90       77              1                   0           9
# 159         31       69              6                   0          11
#
#      speechiness_%
# 93               4
# 120              4
# 131              4
# 150              5
# 159              4
#
# [5 rows x 24 columns]

# %%
hit_songs = df[
    (df['bpm'].between(95, 125)) &
    (df['danceability_%'].between(60, 85)) &
    (df['energy_%'].between(60, 85)) &
    (df['speechiness_%'].between(3, 10)) &
    (df['acousticness_%'].between(0, 35)) &
    (df['mode'] == 'Major')
]

hit_songs[['track_name', 'artist(s)_name', 'bpm', 'danceability_%', 'energy_%']]
# Out:
#                                             track_name  \
# 0                  Seven (feat. Latto) (Explicit Ver.)
# 12                                             Flowers
# 19                                          Like Crazy
# 21   I Can See You (Taylorï¿½ï¿½ï¿½s Version) (From...
# 33                                           Anti-Hero
# 35                                     Los del Espacio
# 37                                         Blank Space
# 38                                               Style
# 45                                     Angels Like You
# 73                                     Sweater Weather
# 79                                     CORAZï¿½ï¿½N VA
# 90                                            Fast Car
# 106                            Cold Heart - PNAU Remix
# 107                                         Dandelions
# 112                                            LAGUNAS
# 113                            Mine (Taylor's Version)
# 162                                          One Dance
# 164                                    Save Your Tears
# 187                                            Circles
# 188                               Just The Way You Are
# 195                       Have You Ever Seen The Rain?
# 206                                     Hits Different
# 290                                          Shut Down
# 293                       Like Crazy (English Version)
# 303                                              10:35
# 308                                 Late Night Talking
# 310       Save Your Tears (with Ariana Grande) (Remix)
# 312                                               VOID
# 316                                          You Proof
# 361        I Like You (A Happier Song) (with Doja Cat)
# 385                          VIBE (feat. Jimin of BTS)
# 393                                  Jhoome Jo Pathaan
# 440                                           Payphone
# 494                                              Party
# 501                                          Sacrifice
# 516                           Kiss Me More (feat. SZA)
# 525                    One Right Now (with The Weeknd)
# 527                                  Mon Amour - Remix
# 538                             Donï¿½ï¿½ï¿½t Break My
# 568                                   Lost in the Fire
# 580                                           Acapulco
# 585                                What Else Can I Do?
# 593                                Rolling in the Deep
# 611                                           Ley Seca
# 616                                     Take My Breath
# 636     Leave Before You Love Me (with Jonas Brothers)
# 637                                Permission to Dance
# 660                                 Ginseng Strip 2002
# 695                                          Adore You
# 699                         Bam Bam (feat. Ed Sheeran)
# 788                                Ensï¿½ï¿½ï¿½ï¿½ame
# 799                        Stefania (Kalush Orchestra)
# 828                       Music For a Sushi Restaurant
# 866                                  Betty (Get Money)
# 870                                               MORE
# 920                                         BABY OTAKU
# 937                                         Circo Loco
# 951                                      En La De Ella
#
#                                         artist(s)_name  bpm  danceability_%  \
# 0                                     Latto, Jung Kook  125              80
# 12                                         Miley Cyrus  118              71
# 19                                               Jimin  120              63
# 21                                        Taylor Swift  123              69
# 33                                        Taylor Swift   97              64
# 35   Big One, Duki, Lit Killah, Maria Becerra, FMK,...  120              81
# 37                                        Taylor Swift   96              75
# 38                                        Taylor Swift   95              60
# 45                                         Miley Cyrus  122              67
# 73                                   The Neighbourhood  124              61
# 79                                       Maria Becerra   98              68
# 90                                          Luke Combs   98              71
# 106                         Dua Lipa, Elton John, Pnau  116              80
# 107                                            Ruth B.  117              61
# 112                          Jasiel Nuï¿½ï¿½ez, Peso P  116              77
# 113                                       Taylor Swift  121              65
# 162                                Drake, WizKid, Kyla  104              77
# 164                                         The Weeknd  118              68
# 187                                        Post Malone  120              70
# 188                                         Bruno Mars  109              63
# 195                       Creedence Clearwater Revival  116              74
# 206                                       Taylor Swift  106              67
# 290                                          BLACKPINK  110              82
# 293                                              Jimin  120              62
# 303                                Tiï¿½ï¿½sto, Tate M  120              70
# 308                                       Harry Styles  115              71
# 310                          Ariana Grande, The Weeknd  118              65
# 312                                   Melanie Martinez  100              72
# 316                                      Morgan Wallen  120              73
# 361                              Post Malone, Doja Cat  101              74
# 385                                     TAEYANG, Jimin  100              79
# 393  Arijit Singh, Vishal Dadlani, Sukriti Kakar, V...  105              82
# 440                              Maroon 5, Wiz Khalifa  110              74
# 494                          Bad Bunny, Rauw Alejandro   97              83
# 501                                         The Weeknd  122              70
# 516                                      SZA, Doja Cat  111              77
# 525                            The Weeknd, Post Malone   97              68
# 527                                     Aitana, zzoilo  116              75
# 538                                         The Weeknd  122              77
# 568                          The Weeknd, Gesaffelstein  101              66
# 580                                       Jason Derulo  122              77
# 585                  Stephanie Beatriz, Diane Guerrero  120              72
# 593                                              Adele  105              73
# 611                              Anuel Aa, Jhay Cortez  105              76
# 616                                         The Weeknd  121              75
# 636                         Marshmello, Jonas Brothers  120              72
# 637                                                BTS  125              70
# 660                                          Yung Lean  115              60
# 695                                       Harry Styles   99              68
# 699                         Camila Cabello, Ed Sheeran   95              76
# 788                                          Bad Bunny  105              81
# 799                                             KALUSH  105              83
# 828                                       Harry Styles  107              72
# 866                                         Yung Gravy  102              73
# 870                                             j-hope   97              78
# 920  Fran C, Polima WestCoast, Nickoog Clk, Pablito...  102              84
# 937                                   Drake, 21 Savage  104              73
# 951                                 Feid, Sech, Jhayco   97              82
#
#      energy_%
# 0          83
# 12         68
# 19         73
# 21         76
# 33         63
# 35         68
# 37         68
# 38         79
# 45         64
# 73         81
# 79         79
# 90         60
# 106        80
# 107        69
# 112        62
# 113        78
# 162        63
# 164        82
# 187        75
# 188        85
# 195        70
# 206        78
# 290        69
# 293        76
# 303        79
# 308        73
# 310        79
# 312        66
# 316        85
# 361        69
# 385        68
# 393        74
# 440        74
# 494        80
# 501        79
# 516        66
# 525        78
# 527        76
# 538        62
# 568        68
# 580        79
# 585        71
# 593        76
# 611        84
# 616        74
# 636        72
# 637        74
# 660        71
# 695        77
# 699        70
# 788        79
# 799        82
# 828        72
# 866        75
# 870        72
# 920        75
# 937        61
# 951        77

# %% [markdown]
# This gives me a list of songs that fit the characteristics I identified as common among hits.

# %% [markdown]
# I chose Blinding Lights because it’s one of the most successful songs in recent years. When I looked at its values, most of them matched the ranges I identified earlier. The BPM is 171, which is faster than the typical mid‑tempo range, but still works because of its retro dance style. Its energy score is 80, which fits right into the common range for popular tracks. Danceability is also high at 80, showing that it’s rhythmically engaging.
#
# Speechiness is low, acousticness is zero, and the song is in a major mode — all of which match the patterns I saw in the dataset. Even though the tempo is on the higher end, the rest of the features line up with the “hit recipe.”
#
# This shows that while some hit songs push the boundaries in one area, they still follow most of the common traits found in successful tracks.
